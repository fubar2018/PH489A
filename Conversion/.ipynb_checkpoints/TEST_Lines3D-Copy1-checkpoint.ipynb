# %%
import matplotlib
matplotlib.use('Agg')

bagfile = "lines3d_2016-05-25-10-58-55.bag"

# %%
# %run bag2csv.py $bagfile
# Out:
# reading only 1 bagfile: lines3d_2016-05-25-10-58-55.bag
# reading file 1 of  1: lines3d_2016-05-25-10-58-55.bag
# Done reading all 1 bag files.

# %%
# %matplotlib inline
bagfile = "lines3d_2016-05-25-10-58-55.bag"
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 15, 8  # that's default image size for this interactive session
import numpy as np
from datetime import datetime
import csv
import sys
csv.field_size_limit(sys.maxsize)
import ast

csvarray = []
with open(bagfile[:-4] + "/_slash_vision3D_slash_lines.csv",'rb') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        csvarray.append(row)
columnnames = csvarray.pop(0)        
        
dataarray = []
for row in csvarray:
    dataarray.append(np.array(row[29])

#data = np.fromregex(bagfile[:-4] + "/_slash_vision3D_slash_lines.csv", regexp = r"\[[[0-9_]?[, [0-9_]*\]",dtype = str)
#print data

#data = np.genfromtxt(bagfile[:-4] + "/_slash_vision3D_slash_lines.csv", delimiter='"', skip_header=1,skip_footer=0,dtype=float,unpack=True)
#(prearray,postarray) = data[:2],data[2:]

#data2 = np.genfromtxt(prearray, delimiter=',', skip_header=1,skip_footer=0,dtype=float,unpack=True)
#(rosbagTimestamp,header,seq,stamp,secs,nsecs,frame_id,height,width,fields,name1,offset1,datatype1,count1,name2,offset2,datatype2,count2,name3,offset3,datatype3,count3,name4,offset4,datatype4,count4,is_bigendian,point_step,row_step),rest = data2[:29],data2[29:]

#data = np.genfromtxt(bagfile[:-4] + "/_slash_vision3D_slash_lines.csv", delimiter=',', skip_header=1,skip_footer=0,dtype=float,unpack=True)[:31]
#(rosbagTimestamp,header,seq,stamp,secs,nsecs,frame_id,height,width,fields,name1,offset1,datatype1,count1,name2,offset2,datatype2,count2,name3,offset3,datatype3,count3,name4,offset4,datatype4,count4,is_bigendian,point_step,row_step,data,is_dense),rest = data[:31],data[31:]

# %%
points = dataarray[0]

points
# Out:
# '[81, 222, 215, 64, 221, 229, 18, 192, 203, 103, 62, 64, 0, 0, 128, 63, 255, 255, 255, 0, 0, 0, 0, 0, 144, 207, 49, 77, 252, 127, 0, 0, 253, 4, 215, 64, 62, 223, 18, 192, 26, 168, 61, 64, 0, 0, 128, 63, 255, 255, 255, 0, 0, 0, 0, 0, 144, 207, 49, 77, 252, 127, 0, 0, 55, 199, 214, 64, 40, 66, 19, 192, 157, 113, 61, 64, 0, 0, 128, 63, 255, 255, 255, 0, 0, 0, 0, 0, 144, 207, 49, 77, 252, 127, 0, 0, 205, 106, 214, 64, 171, 143, 19, 192, 26, 32, 61, 64, 0, 0, 128, 63, 255, 255, 255, 0, 0, 0, 0, 0, 144, 207, 49, 77, 252, 127, 0, 0, 19, 240, 213, 64, 196, 199, 19, 192, 218, 179, 60, 64, 0, 0, 128, 63, 255, 255, 255, 0, 0, 0, 0, 0, 144, 207, 49, 77, 252, 127, 0, 0, 50, 194, 213, 64, 132, 52, 20, 192, 98, 139, 60, 64, 0, 0, 128, 63, 255, 255, 255, 0, 0, 0, 0, 0, 144, 207, 49, 77, 252, 127, 0, 0, 81, 222, 215, 64, 9, 88, 18, 192, 248, 217, 61, 64, 0, 0, 128, 63, 255, 255, 255, 0, 0, 0, 0, 0, 144, 207, 49, 77, 252, 127, 0, 0, 111, 91, 214, 64, 151, 222, 17, 192, 183, 133, 60, 64, 0, 0, 128, 63,
# ...
