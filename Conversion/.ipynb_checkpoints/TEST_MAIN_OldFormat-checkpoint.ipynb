# %%
#Primary Jupyter python script for analysis of BAG file data from IGVC runs. Made by 2LT John Oberholtzer
#Updated 03JUN2016

#Checklist for operation:
#1. Change "Suffix" to appropriate ending from runs.
#2. Change the booleans on the FLAG list below to correspond with which BAG files are available. Adjust as necessary.
#3. Comment or otherwise disable any tests you do not wish to run in their corresponding cells.
#4. Click Cells>Run All to execute

#This file will require updating if rostopics are moved from one bag file to another as the references are hardcoded.
import matplotlib
import csv
import sys
import ast
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
from datetime import datetime
from struct import *
from mpl_toolkits.mplot3d import Axes3D
csv.field_size_limit(sys.maxsize)
matplotlib.use('Agg')
# %matplotlib nbagg
pylab.rcParams['figure.figsize'] = 15, 8  # that's default image size for this interactive session

#Every BAG file should have this suffix. Example: lines3d_2016-05-26-10-34-51.bag
#If some are off by one number feel free to rename them.
suffix = "_2016-05-26-10-34-51"

#The folder the BAG files are in should be named as RUN + the suffix. Example: RUN_2016-05-26-10-34-51
bagfolder = "RUN" + suffix + "/"

bagfile_lines3d = "lines3d"+ suffix + ".bag"
bagfile_red3d = "red3d"+ suffix + ".bag"
bagfile_blue3d = "blue3d"+ suffix + ".bag"
bagfile_gps_fix = "gps_fix"+ suffix + ".bag"
bagfile_disparity =  "disparity"+ suffix + ".bag"
bagfile_imu_raw = "imu_raw"+ suffix + ".bag"
bagfile_rectified = "rectified"+ suffix + ".bag"
bagfile_other = "other"+ suffix + ".bag"
bagfile_imudata = "imudata"+ suffix + ".bag"
bagfile_pointcloud = "pointcloud"+ suffix + ".bag"

#Following Booleans are for whether or not certain BAG files are present. The exception handling isnt working
#at the moment, so change the value to False where a BAG file is not available.
FLAG_lines3d = True
FLAG_red3d = True
FLAG_blue3d = True
FLAG_gps_fix = True
FLAG_disparity = True
FLAG_imu_raw= True
FLAG_rectified = False
FLAG_other = False
FLAG_imudata = False
FLAG_pointcloud = False

print("Setup Finished")
# Out:
# /usr/local/lib/python2.7/dist-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# Setup Finished
# /usr/local/lib/python2.7/dist-packages/matplotlib/__init__.py:1350: UserWarning:  This call to matplotlib.use() has no effect
# because the backend has already been chosen;
# matplotlib.use() must be called *before* pylab, matplotlib.pyplot,
# or matplotlib.backends is imported for the first time.
#
#   warnings.warn(_use_error_msg)

# %%
#CONVERSION FROM .BAG to .CSV, attempts to check each bagfile accordingly.
#If aware that a .BAG file is not present, manually uncheck flag. Error catching not functional at the moment.

if FLAG_lines3d == True:
    try:
        # %run bag2csv_v2.py $bagfolder $bagfile_lines3d
    except Exception as e:
        print(e)
        FLAG_lines3d = False
  
        
if FLAG_red3d == True:
    try:
        # %run bag2csv_v2.py $bagfolder $bagfile_red3d
    except Exception as e:
        print(e) 
        FLAG_red3d = False
    
    
if FLAG_blue3d == True:
    try:
        # %run bag2csv_v2.py $bagfolder $bagfile_blue3d
    except Exception as e:
        print(e) 
        FLAG_blue3d = False
    
       
if FLAG_gps_fix == True:
    try:
        # %run bag2csv_v2.py $bagfolder $bagfile_gps_fix
    except Exception as e:
        print(e)
        FLAG_gps_fix = False
   
    
if FLAG_disparity == True:
    try:
        # %run bag2csv_v2.py $bagfolder $bagfile_disparity
    except Exception as e:
        print(e)
        FLAG_disparity = False
 
        
if FLAG_imu_raw == True:
    try:
        # %run bag2csv_v2.py $bagfolder $bagfile_imu_raw
    except Exception as e:
        print(e)
        FLAG_imu_raw = False

        
if FLAG_rectified == True:
    try:
        # %run bag2csv_v2.py $bagfolder $bagfile_rectified
    except Exception as e:
        print(e)
        FLAG_rectified = False
 
    
if FLAG_other == True:
    try:
        # %run bag2csv_v2.py $bagfolder $bagfile_other
    except Exception as e:
        print(e)
        FLAG_other = False  
   
        
if FLAG_imudata == True:
    try:
        # %run bag2csv_v2.py $bagfolder $bagfile_imudata
    except Exception as e:
        print(e)
        FLAG_imudata = False
    
if FLAG_pointcloud == True:
    try:
       # %run bag2csv_v2.py $bagfolder $bagfile_pointcloud
    except Exception as e:
        print(e)
        FLAG_pointcloud = False
    
print str(FLAG_lines3d)
print str(FLAG_red3d)
print str(FLAG_blue3d)
print str(FLAG_gps_fix)
print str(FLAG_disparity)
print str(FLAG_imu_raw)
print str(FLAG_rectified)
print str(FLAG_other)
print str(FLAG_imudata)
print str(FLAG_pointcloud)
# Out:
# reading only 1 bagfile: lines3d_2016-05-26-10-34-51.bag
# reading file 1 of  1: lines3d_2016-05-26-10-34-51.bag
# lines3d_2016-05-26-10-34-51.bag
# Done reading all 1 bag files.
# reading only 1 bagfile: red3d_2016-05-26-10-34-51.bag
# reading file 1 of  1: red3d_2016-05-26-10-34-51.bag
# red3d_2016-05-26-10-34-51.bag
# Done reading all 1 bag files.
# reading only 1 bagfile: blue3d_2016-05-26-10-34-51.bag
# reading file 1 of  1: blue3d_2016-05-26-10-34-51.bag
# blue3d_2016-05-26-10-34-51.bag
# Done reading all 1 bag files.
# reading only 1 bagfile: gps_fix_2016-05-26-10-34-51.bag
# reading file 1 of  1: gps_fix_2016-05-26-10-34-51.bag
# gps_fix_2016-05-26-10-34-51.bag
# Done reading all 1 bag files.
# reading only 1 bagfile: disparity_2016-05-26-10-34-51.bag
# reading file 1 of  1: disparity_2016-05-26-10-34-51.bag
# disparity_2016-05-26-10-34-51.bag
# Done reading all 1 bag files.
# reading only 1 bagfile: imu_raw_2016-05-26-10-34-51.bag
# reading file 1 of  1: imu_raw_2016-05-26-10-34-51.bag
# imu_raw_2016-05-26-10-34-51.bag
# Done reading all 1 bag files.
# reading only 1 bagfile: rectified_2016-05-26-10-34-51.bag
# reading file 1 of  1: rectified_2016-05-26-10-34-51.bag
# rectified_2016-05-26-10-34-51.bag
# Done reading all 1 bag files.
# True
# True
# True
# True
# True
# True
# True
# False
# False
# False

# %%
#White Line Processing (RUN IF USING ANALYSIS)

if FLAG_lines3d == True:
    linescsvarray = []
    with open(bagfolder + bagfile_lines3d[:-4] + "/_slash_vision3D_slash_lines.csv",'rb') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            linescsvarray.append(row)
    linescolumnnames = linescsvarray.pop(0)        
        
    linesdataarray = []
    for row in linescsvarray:
        linesdataarray.append(ast.literal_eval(row[29]))

    rawlinespoints = linesdataarray[0]
    linespoints = [rawlinespoints[x:x+32] for x in range(0, len(rawlinespoints),32)]
    
    lineslist_x = []
    lineslist_y = []
    lineslist_z = []

    for lines_increment in range(0,len(linespoints)):
        lines_transition = str(bytearray(linespoints[lines_increment]))
        lines_values = unpack('ffffffff',lines_transition)
        lineslist_x.append(lines_values[0])
        lineslist_y.append(lines_values[1])
        lineslist_z.append(lines_values[2])

# %%
#Red3D Processing (RUN IF USING ANALYSIS)

if FLAG_red3d == True:
    redcsvarray = []
    with open(bagfolder + bagfile_red3d[:-4] + "/_slash_vision3D_slash_red.csv",'rb') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            redcsvarray.append(row)
    redcolumnnames = redcsvarray.pop(0)        
        
    reddataarray = []
    for row in redcsvarray:
        reddataarray.append(ast.literal_eval(row[29]))

    rawredpoints = reddataarray[0]
    redpoints = [rawredpoints[x:x+32] for x in range(0, len(rawredpoints),32)]
    
    redlist_x = []
    redlist_y = []
    redlist_z = []

    for red_increment in range(0,len(redpoints)):
        red_transition = str(bytearray(redpoints[red_increment]))
        red_values = unpack('ffffffff',red_transition)
        redlist_x.append(lines_values[0])
        redlist_y.append(lines_values[1])
        redlist_z.append(lines_values[2])

# %%
#Blue3D Processing (RUN IF USING ANALYSIS)

if FLAG_blue3d == True:
    bluecsvarray = []
    with open(bagfolder + bagfile_blue3d[:-4] + "/_slash_vision3D_slash_blue.csv",'rb') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            bluecsvarray.append(row)
    bluecolumnnames = bluecsvarray.pop(0)        
        
    bluedataarray = []
    for row in bluecsvarray:
        bluedataarray.append(ast.literal_eval(row[29]))

    rawbluepoints = bluedataarray[0]
    bluepoints = [rawbluepoints[x:x+32] for x in range(0, len(rawbluepoints),32)]
    
    bluelist_x = []
    bluelist_y = []
    bluelist_z = []

    for blue_increment in range(0,len(bluepoints)):
        blue_transition = str(bytearray(bluepoints[blue_increment]))
        blue_values = unpack('ffffffff',blue_transition)
        bluelist_x.append(lines_values[0])
        bluelist_y.append(lines_values[1])
        bluelist_z.append(lines_values[2])

# %%
#GPS AND TF PROCESSING (RUN IF USING ANALYSIS)
if FLAG_other == True:
    TFcsvarray = []
    with open(bagfolder + bagfile_other[:-4] + "/_slash_tf.csv",'rb') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            TFcsvarray.append(row)
    TFcolumnnames = TFcsvarray.pop(0)
    TFdataex = TFcsvarray[0]
    tx= []
    ty= []
    tz= []
    for row in TFcsvarray:
        tx.append(row[11])
        ty.append(row[12])
        tz.append(row[13])
    
    
if FLAG_gps_fix == True:
    GPScsvarray = []
    with open(bagfolder + bagfile_gps_fix[:-4] + "/_slash_gps_slash_fix.csv",'rb') as csvfile:
        reader = csv.reader(csvfile)
        for row in reader:
            GPScsvarray.append(row)
    GPScolumnnames = GPScsvarray.pop(0)
    GPSdataex = GPScsvarray[0]
    lat= []
    lon= []
    alt= []
    for row in GPScsvarray:
        lat.append(row[10])
        lon.append(row[11])
        alt.append(row[12])

# %%
#GPS AND TF 2D GRAPHING FOR LOCATION
if FLAG_other == True:
    plt.plot(tx,ty, 'ro')
    plt.show()
if FLAG_gps_fix == True:
    plt.plot(tx,ty, 'g^')
    plt.show()
# Out:
# <img src="data:image/png;base64,...">

# %%
#WHITE LINE 3D GRAPHING
if FLAG_lines3d == True:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(lineslist_x, lineslist_y, lineslist_z, zdir='z', s=20, c='b')
# Out:
# <img src="data:image/png;base64,...">

# %%
#RED POINT 3D GRAPHING
if FLAG_red3d == True:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(redlist_x, redlist_y, redlist_z, zdir='z', s=20, c='b')
# Out:
# <img src="data:image/png;base64,...">

# %%
#BLUE POINT 3D GRAPHING
if FLAG_blue3d == True:
    fig = plt.figure()
    ax = fig.add_subplot(111, projection='3d')
    ax.scatter(bluelist_x, bluelist_y, bluelist_z, zdir='z', s=20, c='b')
# Out:
# <img src="data:image/png;base64,...">
