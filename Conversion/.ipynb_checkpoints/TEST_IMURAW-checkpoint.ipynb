# %%
import matplotlib
matplotlib.use('Agg')

bagfile = "imu_raw_2016-05-26-16-24-32.bag"

# %%
# %run bag2csv.py $bagfile
# Out:
# reading only 1 bagfile: imu_raw_2016-05-26-16-24-32.bag
# reading file 1 of  1: imu_raw_2016-05-26-16-24-32.bag
# Done reading all 1 bag files.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 15, 8  # that's default image size for this interactive session
import numpy as np
from datetime import datetime
import csv
import sys
csv.field_size_limit(sys.maxsize)

csvarray = []
with open(bagfile[:-4] + "/_slash_imu_slash_raw.csv",'rb') as csvfile:
    reader = csv.reader(csvfile)
    for row in reader:
        csvarray.append(row)
columnnames = csvarray.pop(0)
dataex = csvarray[0]

time = []
linvelx= []
linvely= []
linvelz= []


for row in csvarray:
    time.append(row[0])
    linvelx.append(row[19])
    linvely.append(row[20])
    linvelz.append(row[21])

# %%
plt.plot(time,linvelx,'ro')
plt.show()
plt.plot(time,linvely,'bo')
plt.show()
#print columnnames[19]
#print "\n"
#print dataex
